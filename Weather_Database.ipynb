# %%
#Import the dependencies

from citipy import citipy
from config import weather_api_key
import requests
import numpy as np
import time
from datetime import datetime

import pandas as pd

# %%
#Creating a set of random latitude and longitude combinations

lats = np.random.uniform(low = -90, high = 90, size = 1500)

lngs = np.random.uniform(low = -180, high = 180, size = 1500)

lat_lngs = zip(lats,lngs)

lat_lngs

# %%
#Add latitudes and longitudes to a list

coordinates = list(lat_lngs)

# %%
cities = []

#Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #add cities that are not in the list
    if city not in cities:
        
        cities.append(city)

# %%
#Print the lenght of the new list
print(len(cities))

print(cities[:5])
# Out:
# 626
# ['hithadhoo', 'balabac', 'yarmouth', 'karlskrona', 'rikitea']

# %%
#Create an empty list to hold the weather data.

city_data = []

#Create the url


url = f'https://api.openweathermap.org/data/2.5/weather?units=imperial&appid={weather_api_key}'

#Print the beginning of the logging.

print('Beginning Data Retrieval        ')

print('--------------------------------')

#Create the counters.

record_count = 1

set_count = 1

#Loop through all the cities in our list.
    
for i, city in enumerate(cities):
    #Group cities in sets of 50 for logging purposes.
    if(i % 50 == 0 and i>= 50):
        
        set_count += 1

        record_count = 1

        time.sleep(60)

    #Create enpoint URL with each city.

    city_url = url+'&q='+city.replace(' ','+')

    #log the URL, record, and set numbers and the city

    print(f'Processing Record {record_count} of Set{set_count} | {city}')

    #Add 1 to the record count.

    record_count += 1
        
    #Run an API request for each of the cities

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set1 | hithadhoo
# Processing Record 2 of Set1 | balabac
# Processing Record 3 of Set1 | yarmouth
# Processing Record 4 of Set1 | karlskrona
# Processing Record 5 of Set1 | rikitea
# Processing Record 6 of Set1 | albany
# Processing Record 7 of Set1 | avarua
# Processing Record 8 of Set1 | hays
# Processing Record 9 of Set1 | polyarnyy
# Processing Record 10 of Set1 | hobart
# Processing Record 11 of Set1 | aranos
# Processing Record 12 of Set1 | ayios matthaios
# City not found. Skipping...
# Processing Record 13 of Set1 | coari
# Processing Record 14 of Set1 | port shepstone
# Processing Record 15 of Set1 | ushuaia
# Processing Record 16 of Set1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set1 | narsaq
# Processing Record 18 of Set1 | port elizabeth
# Processing Record 19 of Set1 | busselton
# Processing Record 20 of Set1 | zabaykalsk
# Processing Record 21 of Set1 | punta arenas
# Processing Record 22 of Set1 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set1 | hasaki
# Processing Record 24 of Set1 | chuy
# Processing Record 25 of Set1 | quatre cocos
# Processing Record 26 of Set1 | grosseto
# Processing Record 27 of Set1 | salalah
# Processing Record 28 of Set1 | san cristobal
# Processing Record 29 of Set1 | bengkulu
# Processing Record 30 of Set1 | east london
# Processing Record 31 of Set1 | soyo
# Processing Record 32 of Set1 | makubetsu
# Processing Record 33 of Set1 | cayenne
# Processing Record 34 of Set1 | butaritari
# Processing Record 35 of Set1 | yellowknife
# Processing Record 36 of Set1 | vaini
# Processing Record 37 of Set1 | guskhara
# Processing Record 38 of Set1 | pattukkottai
# Processing Record 39 of Set1 | vicksburg
# Processing Record 40 of Set1 | green river
# Processing Record 41 of Set1 | bluff
# Processing Record 42 of Set1 | bredasdorp
# Processing Record 43 of Set1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set1 | kapaa
# Processing Record 45 of Set1 | laguna
# Processing Record 46 of Set1 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set1 | labuhan
# Processing Record 48 of Set1 | kenai
# Processing Record 49 of Set1 | dikson
# Processing Record 50 of Set1 | hermanus
# Processing Record 1 of Set2 | mar del plata
# Processing Record 2 of Set2 | sovetskiy
# Processing Record 3 of Set2 | burley
# Processing Record 4 of Set2 | portland
# Processing Record 5 of Set2 | lagoa
# Processing Record 6 of Set2 | new norfolk
# Processing Record 7 of Set2 | seoul
# Processing Record 8 of Set2 | tuktoyaktuk
# Processing Record 9 of Set2 | corinth
# Processing Record 10 of Set2 | kerteh
# City not found. Skipping...
# Processing Record 11 of Set2 | georgetown
# Processing Record 12 of Set2 | edson
# Processing Record 13 of Set2 | lahat
# Processing Record 14 of Set2 | san patricio
# Processing Record 15 of Set2 | barrow
# Processing Record 16 of Set2 | canton
# Processing Record 17 of Set2 | monster
# Processing Record 18 of Set2 | hualmay
# Processing Record 19 of Set2 | codrington
# Processing Record 20 of Set2 | humberto de campos
# Processing Record 21 of Set2 | hamilton
# Processing Record 22 of Set2 | laurel
# Processing Record 23 of Set2 | airai
# Processing Record 24 of Set2 | shenjiamen
# Processing Record 25 of Set2 | vila franca do campo
# Processing Record 26 of Set2 | santa fe
# Processing Record 27 of Set2 | kodiak
# Processing Record 28 of Set2 | mataura
# Processing Record 29 of Set2 | chicama
# Processing Record 30 of Set2 | gaoua
# Processing Record 31 of Set2 | mizdah
# Processing Record 32 of Set2 | ust-nera
# Processing Record 33 of Set2 | jumla
# Processing Record 34 of Set2 | udachnyy
# Processing Record 35 of Set2 | hilo
# Processing Record 36 of Set2 | sile
# Processing Record 37 of Set2 | padang
# Processing Record 38 of Set2 | sao joao do piaui
# Processing Record 39 of Set2 | sheregesh
# Processing Record 40 of Set2 | qaanaaq
# Processing Record 41 of Set2 | atuona
# Processing Record 42 of Set2 | wukari
# Processing Record 43 of Set2 | missoula
# Processing Record 44 of Set2 | bethel
# Processing Record 45 of Set2 | kerchevskiy
# Processing Record 46 of Set2 | chokurdakh
# Processing Record 47 of Set2 | khatanga
# Processing Record 48 of Set2 | pierre
# Processing Record 49 of Set2 | kaitangata
# Processing Record 50 of Set2 | ahipara
# Processing Record 1 of Set3 | thompson
# Processing Record 2 of Set3 | nantucket
# Processing Record 3 of Set3 | grindavik
# Processing Record 4 of Set3 | carnarvon
# Processing Record 5 of Set3 | viedma
# Processing Record 6 of Set3 | saint george
# Processing Record 7 of Set3 | svetlogorsk
# Processing Record 8 of Set3 | kaputa
# Processing Record 9 of Set3 | jamestown
# Processing Record 10 of Set3 | ferme-neuve
# Processing Record 11 of Set3 | sisimiut
# Processing Record 12 of Set3 | amderma
# City not found. Skipping...
# Processing Record 13 of Set3 | cape town
# Processing Record 14 of Set3 | sorland
# Processing Record 15 of Set3 | avera
# Processing Record 16 of Set3 | clyde river
# Processing Record 17 of Set3 | linjiang
# Processing Record 18 of Set3 | andippatti
# Processing Record 19 of Set3 | touros
# Processing Record 20 of Set3 | lebu
# Processing Record 21 of Set3 | qui nhon
# Processing Record 22 of Set3 | sola
# Processing Record 23 of Set3 | lakselv
# Processing Record 24 of Set3 | biltine
# Processing Record 25 of Set3 | kahului
# Processing Record 26 of Set3 | vieste
# Processing Record 27 of Set3 | ancud
# Processing Record 28 of Set3 | delijan
# Processing Record 29 of Set3 | olafsvik
# Processing Record 30 of Set3 | marshall
# Processing Record 31 of Set3 | halalo
# City not found. Skipping...
# Processing Record 32 of Set3 | cabo san lucas
# Processing Record 33 of Set3 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set3 | hovd
# Processing Record 35 of Set3 | crixas
# Processing Record 36 of Set3 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set3 | port alfred
# Processing Record 38 of Set3 | tidore
# City not found. Skipping...
# Processing Record 39 of Set3 | biak
# Processing Record 40 of Set3 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set3 | sembakung
# Processing Record 42 of Set3 | baracoa
# Processing Record 43 of Set3 | los llanos de aridane
# Processing Record 44 of Set3 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set3 | kulhudhuffushi
# Processing Record 46 of Set3 | sal rei
# Processing Record 47 of Set3 | hirara
# Processing Record 48 of Set3 | esperance
# Processing Record 49 of Set3 | castro
# Processing Record 50 of Set3 | awjilah
# Processing Record 1 of Set4 | sevlievo
# Processing Record 2 of Set4 | berani
# Processing Record 3 of Set4 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set4 | la paz
# Processing Record 5 of Set4 | bor
# Processing Record 6 of Set4 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set4 | tiksi
# Processing Record 8 of Set4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set4 | champerico
# Processing Record 10 of Set4 | shingu
# Processing Record 11 of Set4 | jardim
# Processing Record 12 of Set4 | shitanjing
# Processing Record 13 of Set4 | rungata
# City not found. Skipping...
# Processing Record 14 of Set4 | cidreira
# Processing Record 15 of Set4 | north bend
# Processing Record 16 of Set4 | victoria
# Processing Record 17 of Set4 | asau
# Processing Record 18 of Set4 | waconia
# Processing Record 19 of Set4 | bonthe
# Processing Record 20 of Set4 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set4 | kirovskiy
# Processing Record 22 of Set4 | bourail
# Processing Record 23 of Set4 | san jose del palmar
# Processing Record 24 of Set4 | kruisfontein
# Processing Record 25 of Set4 | ribeira grande
# Processing Record 26 of Set4 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set4 | atlantic city
# Processing Record 28 of Set4 | teahupoo
# Processing Record 29 of Set4 | upernavik
# Processing Record 30 of Set4 | berdigestyakh
# Processing Record 31 of Set4 | dir
# Processing Record 32 of Set4 | korla
# Processing Record 33 of Set4 | nador
# Processing Record 34 of Set4 | bambous virieux
# Processing Record 35 of Set4 | ijaki
# City not found. Skipping...
# Processing Record 36 of Set4 | acapulco
# Processing Record 37 of Set4 | bathsheba
# Processing Record 38 of Set4 | wahran
# City not found. Skipping...
# Processing Record 39 of Set4 | sitka
# Processing Record 40 of Set4 | iqaluit
# Processing Record 41 of Set4 | delhi
# Processing Record 42 of Set4 | saskylakh
# Processing Record 43 of Set4 | puerto ayora
# Processing Record 44 of Set4 | caronport
# Processing Record 45 of Set4 | meulaboh
# Processing Record 46 of Set4 | leh
# Processing Record 47 of Set4 | horuphav
# Processing Record 48 of Set4 | hof
# Processing Record 49 of Set4 | sucy-en-brie
# Processing Record 50 of Set4 | saint-joseph
# Processing Record 1 of Set5 | kungurtug
# Processing Record 2 of Set5 | lampa
# Processing Record 3 of Set5 | galgani
# City not found. Skipping...
# Processing Record 4 of Set5 | huilong
# Processing Record 5 of Set5 | habiganj
# Processing Record 6 of Set5 | nome
# Processing Record 7 of Set5 | bilma
# Processing Record 8 of Set5 | nikolskoye
# Processing Record 9 of Set5 | tasiilaq
# Processing Record 10 of Set5 | pevek
# Processing Record 11 of Set5 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 12 of Set5 | adrar
# Processing Record 13 of Set5 | port lincoln
# Processing Record 14 of Set5 | dingle
# Processing Record 15 of Set5 | chapleau
# Processing Record 16 of Set5 | inverness
# Processing Record 17 of Set5 | ambon
# Processing Record 18 of Set5 | nanakuli
# Processing Record 19 of Set5 | talcahuano
# Processing Record 20 of Set5 | aklavik
# Processing Record 21 of Set5 | cherskiy
# Processing Record 22 of Set5 | arraial do cabo
# Processing Record 23 of Set5 | tucuman
# Processing Record 24 of Set5 | dakar
# Processing Record 25 of Set5 | yucca valley
# Processing Record 26 of Set5 | biryusinsk
# Processing Record 27 of Set5 | dargaville
# Processing Record 28 of Set5 | khani
# Processing Record 29 of Set5 | bubaque
# Processing Record 30 of Set5 | faya
# Processing Record 31 of Set5 | aquidauana
# Processing Record 32 of Set5 | acuexcomac
# Processing Record 33 of Set5 | togur
# Processing Record 34 of Set5 | binga
# Processing Record 35 of Set5 | socorro
# Processing Record 36 of Set5 | sorong
# Processing Record 37 of Set5 | mudhol
# Processing Record 38 of Set5 | hokitika
# Processing Record 39 of Set5 | nanortalik
# Processing Record 40 of Set5 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set5 | vardo
# Processing Record 42 of Set5 | hong gai
# Processing Record 43 of Set5 | paamiut
# Processing Record 44 of Set5 | ouesso
# Processing Record 45 of Set5 | harindanga
# Processing Record 46 of Set5 | hofn
# Processing Record 47 of Set5 | tabou
# Processing Record 48 of Set5 | lashio
# Processing Record 49 of Set5 | hot springs
# Processing Record 50 of Set5 | sesheke
# Processing Record 1 of Set6 | tanabe
# Processing Record 2 of Set6 | carora
# Processing Record 3 of Set6 | chapais
# Processing Record 4 of Set6 | provideniya
# Processing Record 5 of Set6 | ponta do sol
# Processing Record 6 of Set6 | yukhnov
# Processing Record 7 of Set6 | nyazepetrovsk
# Processing Record 8 of Set6 | eyrarbakki
# Processing Record 9 of Set6 | sioux lookout
# Processing Record 10 of Set6 | severo-kurilsk
# Processing Record 11 of Set6 | iskitim
# Processing Record 12 of Set6 | santa rosalia
# Processing Record 13 of Set6 | broome
# Processing Record 14 of Set6 | lolua
# City not found. Skipping...
# Processing Record 15 of Set6 | bargal
# City not found. Skipping...
# Processing Record 16 of Set6 | chingshui
# City not found. Skipping...
# Processing Record 17 of Set6 | boa vista
# Processing Record 18 of Set6 | bereda
# Processing Record 19 of Set6 | bandarbeyla
# Processing Record 20 of Set6 | lorengau
# Processing Record 21 of Set6 | la ronge
# Processing Record 22 of Set6 | praia
# Processing Record 23 of Set6 | labutta
# City not found. Skipping...
# Processing Record 24 of Set6 | kimbe
# Processing Record 25 of Set6 | puerto del rosario
# Processing Record 26 of Set6 | crab hill
# City not found. Skipping...
# Processing Record 27 of Set6 | yulara
# Processing Record 28 of Set6 | chumikan
# Processing Record 29 of Set6 | geraldton
# Processing Record 30 of Set6 | abu dhabi
# Processing Record 31 of Set6 | paciran
# Processing Record 32 of Set6 | svarstad
# Processing Record 33 of Set6 | kargil
# Processing Record 34 of Set6 | tiznit
# Processing Record 35 of Set6 | olyka
# Processing Record 36 of Set6 | mount gambier
# Processing Record 37 of Set6 | mahebourg
# Processing Record 38 of Set6 | barawe
# City not found. Skipping...
# Processing Record 39 of Set6 | xiaoshi
# Processing Record 40 of Set6 | cockburn town
# Processing Record 41 of Set6 | marrakesh
# Processing Record 42 of Set6 | bulungu
# Processing Record 43 of Set6 | birin
# Processing Record 44 of Set6 | mount isa
# Processing Record 45 of Set6 | menomonie
# Processing Record 46 of Set6 | kostalexis
# Processing Record 47 of Set6 | athabasca
# Processing Record 48 of Set6 | shieli
# Processing Record 49 of Set6 | verkhnyaya inta
# Processing Record 50 of Set6 | saint-philippe
# Processing Record 1 of Set7 | payo
# Processing Record 2 of Set7 | pahalgam
# Processing Record 3 of Set7 | kamyshin
# Processing Record 4 of Set7 | stournaraiika
# City not found. Skipping...
# Processing Record 5 of Set7 | vao
# Processing Record 6 of Set7 | novyy svit
# Processing Record 7 of Set7 | college
# Processing Record 8 of Set7 | morant bay
# Processing Record 9 of Set7 | naze
# Processing Record 10 of Set7 | hammerfest
# Processing Record 11 of Set7 | tarpon springs
# Processing Record 12 of Set7 | tindwari
# Processing Record 13 of Set7 | lincoln
# Processing Record 14 of Set7 | mmabatho
# Processing Record 15 of Set7 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set7 | quelimane
# Processing Record 17 of Set7 | rawson
# Processing Record 18 of Set7 | madimba
# Processing Record 19 of Set7 | jalu
# Processing Record 20 of Set7 | tessalit
# Processing Record 21 of Set7 | constitucion
# Processing Record 22 of Set7 | fairbanks
# Processing Record 23 of Set7 | harnosand
# Processing Record 24 of Set7 | eyl
# Processing Record 25 of Set7 | borger
# Processing Record 26 of Set7 | fuzhou
# Processing Record 27 of Set7 | namatanai
# Processing Record 28 of Set7 | guerrero negro
# Processing Record 29 of Set7 | labuan
# Processing Record 30 of Set7 | zaliztsi
# Processing Record 31 of Set7 | iraucuba
# Processing Record 32 of Set7 | atar
# Processing Record 33 of Set7 | lusaka
# Processing Record 34 of Set7 | bosaso
# Processing Record 35 of Set7 | poronaysk
# Processing Record 36 of Set7 | leshukonskoye
# Processing Record 37 of Set7 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set7 | sechura
# Processing Record 39 of Set7 | longlac
# City not found. Skipping...
# Processing Record 40 of Set7 | nara
# Processing Record 41 of Set7 | ixtapa
# Processing Record 42 of Set7 | kushmurun
# Processing Record 43 of Set7 | toliary
# City not found. Skipping...
# Processing Record 44 of Set7 | kalundborg
# Processing Record 45 of Set7 | kavaratti
# Processing Record 46 of Set7 | luderitz
# Processing Record 47 of Set7 | aquiraz
# Processing Record 48 of Set7 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set7 | volchikha
# Processing Record 50 of Set7 | luwingu
# Processing Record 1 of Set8 | thaba-tseka
# Processing Record 2 of Set8 | bardiyah
# Processing Record 3 of Set8 | kogon
# Processing Record 4 of Set8 | imbituba
# Processing Record 5 of Set8 | palmer
# Processing Record 6 of Set8 | alofi
# Processing Record 7 of Set8 | anadyr
# Processing Record 8 of Set8 | eureka
# Processing Record 9 of Set8 | husavik
# Processing Record 10 of Set8 | krasnyy chikoy
# Processing Record 11 of Set8 | nyurba
# Processing Record 12 of Set8 | pozega
# Processing Record 13 of Set8 | tarudant
# City not found. Skipping...
# Processing Record 14 of Set8 | waingapu
# Processing Record 15 of Set8 | jipijapa
# Processing Record 16 of Set8 | walvis bay
# Processing Record 17 of Set8 | madang
# Processing Record 18 of Set8 | pisco
# Processing Record 19 of Set8 | arenapolis
# Processing Record 20 of Set8 | fort nelson
# Processing Record 21 of Set8 | caravelas
# Processing Record 22 of Set8 | agadez
# Processing Record 23 of Set8 | rolim de moura
# City not found. Skipping...
# Processing Record 24 of Set8 | dong hoi
# Processing Record 25 of Set8 | hami
# Processing Record 26 of Set8 | verkh-usugli
# Processing Record 27 of Set8 | kawalu
# Processing Record 28 of Set8 | souillac
# Processing Record 29 of Set8 | poum
# Processing Record 30 of Set8 | camacha
# Processing Record 31 of Set8 | lima
# Processing Record 32 of Set8 | bandar
# Processing Record 33 of Set8 | chagda
# City not found. Skipping...
# Processing Record 34 of Set8 | narasannapeta
# Processing Record 35 of Set8 | kijang
# Processing Record 36 of Set8 | westport
# Processing Record 37 of Set8 | ugoofaaru
# Processing Record 38 of Set8 | fortuna
# Processing Record 39 of Set8 | saldanha
# Processing Record 40 of Set8 | kuching
# Processing Record 41 of Set8 | berlevag
# Processing Record 42 of Set8 | pangai
# Processing Record 43 of Set8 | davila
# Processing Record 44 of Set8 | grootfontein
# Processing Record 45 of Set8 | uruzgan
# Processing Record 46 of Set8 | san juan
# Processing Record 47 of Set8 | saint anthony
# Processing Record 48 of Set8 | itarema
# Processing Record 49 of Set8 | medina
# Processing Record 50 of Set8 | pangnirtung
# Processing Record 1 of Set9 | holbeach
# Processing Record 2 of Set9 | rabat
# Processing Record 3 of Set9 | boguchany
# Processing Record 4 of Set9 | garowe
# Processing Record 5 of Set9 | havelock
# Processing Record 6 of Set9 | tarsus
# Processing Record 7 of Set9 | silvassa
# Processing Record 8 of Set9 | mackenzie
# Processing Record 9 of Set9 | san joaquin
# Processing Record 10 of Set9 | boyolangu
# Processing Record 11 of Set9 | sydney
# Processing Record 12 of Set9 | ilulissat
# Processing Record 13 of Set9 | reefton
# City not found. Skipping...
# Processing Record 14 of Set9 | zhezkazgan
# Processing Record 15 of Set9 | perth
# Processing Record 16 of Set9 | demyansk
# Processing Record 17 of Set9 | sinkat
# City not found. Skipping...
# Processing Record 18 of Set9 | bendigo
# Processing Record 19 of Set9 | longavi
# Processing Record 20 of Set9 | aloleng
# Processing Record 21 of Set9 | zhigalovo
# Processing Record 22 of Set9 | kloulklubed
# Processing Record 23 of Set9 | siocon
# Processing Record 24 of Set9 | moba
# Processing Record 25 of Set9 | tevriz
# Processing Record 26 of Set9 | impfondo
# Processing Record 27 of Set9 | santo domingo
# Processing Record 28 of Set9 | aflu
# City not found. Skipping...
# Processing Record 29 of Set9 | najran
# Processing Record 30 of Set9 | namtsy
# Processing Record 31 of Set9 | sayyan
# Processing Record 32 of Set9 | vitim
# Processing Record 33 of Set9 | deh rawud
# City not found. Skipping...
# Processing Record 34 of Set9 | torbay
# Processing Record 35 of Set9 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set9 | santa rosa
# Processing Record 37 of Set9 | kirakira
# Processing Record 38 of Set9 | ngunguru
# Processing Record 39 of Set9 | shediac
# Processing Record 40 of Set9 | isangel
# Processing Record 41 of Set9 | shache
# Processing Record 42 of Set9 | zhanaozen
# Processing Record 43 of Set9 | lompoc
# Processing Record 44 of Set9 | ugep
# Processing Record 45 of Set9 | flinders
# Processing Record 46 of Set9 | kyra
# Processing Record 47 of Set9 | ambilobe
# Processing Record 48 of Set9 | ryotsu
# Processing Record 49 of Set9 | henties bay
# Processing Record 50 of Set9 | sterling
# Processing Record 1 of Set10 | onega
# Processing Record 2 of Set10 | mwinilunga
# Processing Record 3 of Set10 | reconquista
# Processing Record 4 of Set10 | tautira
# Processing Record 5 of Set10 | mirnyy
# Processing Record 6 of Set10 | weligama
# Processing Record 7 of Set10 | casper
# Processing Record 8 of Set10 | lyantonde
# Processing Record 9 of Set10 | yen bai
# Processing Record 10 of Set10 | srednekolymsk
# Processing Record 11 of Set10 | necochea
# Processing Record 12 of Set10 | shimoda
# Processing Record 13 of Set10 | sirari
# Processing Record 14 of Set10 | calama
# Processing Record 15 of Set10 | faanui
# Processing Record 16 of Set10 | yar-sale
# Processing Record 17 of Set10 | danshui
# Processing Record 18 of Set10 | coquimbo
# Processing Record 19 of Set10 | alenquer
# Processing Record 20 of Set10 | victor harbor
# Processing Record 21 of Set10 | havoysund
# Processing Record 22 of Set10 | copiapo
# Processing Record 23 of Set10 | kozhva
# Processing Record 24 of Set10 | kabalo
# Processing Record 25 of Set10 | nelson bay
# Processing Record 26 of Set10 | saint-francois
# Processing Record 27 of Set10 | esna
# Processing Record 28 of Set10 | lodja
# Processing Record 29 of Set10 | gajendragarh
# Processing Record 30 of Set10 | gra liyia
# Processing Record 31 of Set10 | pacific grove
# Processing Record 32 of Set10 | kabin buri
# Processing Record 33 of Set10 | marsh harbour
# Processing Record 34 of Set10 | uglekamensk
# Processing Record 35 of Set10 | barcelos
# Processing Record 36 of Set10 | batemans bay
# Processing Record 37 of Set10 | zachagansk
# City not found. Skipping...
# Processing Record 38 of Set10 | murgab
# Processing Record 39 of Set10 | swan hill
# Processing Record 40 of Set10 | maraa
# Processing Record 41 of Set10 | la libertad
# Processing Record 42 of Set10 | maningrida
# Processing Record 43 of Set10 | maceio
# Processing Record 44 of Set10 | buribay
# Processing Record 45 of Set10 | gornopravdinsk
# Processing Record 46 of Set10 | ploufragan
# Processing Record 47 of Set10 | port hardy
# Processing Record 48 of Set10 | rayachoti
# Processing Record 49 of Set10 | karauzyak
# City not found. Skipping...
# Processing Record 50 of Set10 | sao luis
# Processing Record 1 of Set11 | loubomo
# Processing Record 2 of Set11 | mpulungu
# Processing Record 3 of Set11 | hobyo
# Processing Record 4 of Set11 | kerouane
# Processing Record 5 of Set11 | whitehorse
# Processing Record 6 of Set11 | bogovarovo
# Processing Record 7 of Set11 | freeport
# Processing Record 8 of Set11 | muros
# Processing Record 9 of Set11 | koslan
# Processing Record 10 of Set11 | huarmey
# Processing Record 11 of Set11 | aksu
# Processing Record 12 of Set11 | maposeni
# Processing Record 13 of Set11 | shizuishan
# Processing Record 14 of Set11 | luanda
# Processing Record 15 of Set11 | chone
# Processing Record 16 of Set11 | lilongwe
# Processing Record 17 of Set11 | urucara
# Processing Record 18 of Set11 | ovre ardal
# Processing Record 19 of Set11 | jiaonan
# Processing Record 20 of Set11 | tosya
# Processing Record 21 of Set11 | morondava
# Processing Record 22 of Set11 | constantine
# Processing Record 23 of Set11 | fermoy
# Processing Record 24 of Set11 | abha
# Processing Record 25 of Set11 | santa luzia
# Processing Record 26 of Set11 | kostomuksha
# Processing Record 27 of Set11 | berezovyy
# Processing Record 28 of Set11 | longyearbyen
# Processing Record 29 of Set11 | diplo
# Processing Record 30 of Set11 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set11 | port blair
# Processing Record 32 of Set11 | trelew
# Processing Record 33 of Set11 | tocopilla
# Processing Record 34 of Set11 | marathon
# Processing Record 35 of Set11 | xudat
# Processing Record 36 of Set11 | honningsvag
# Processing Record 37 of Set11 | arlit
# Processing Record 38 of Set11 | samusu
# City not found. Skipping...
# Processing Record 39 of Set11 | chinsali
# Processing Record 40 of Set11 | yarkovo
# Processing Record 41 of Set11 | agirish
# Processing Record 42 of Set11 | zhigansk
# Processing Record 43 of Set11 | haines junction
# Processing Record 44 of Set11 | saint-pacome
# City not found. Skipping...
# Processing Record 45 of Set11 | hopfgarten
# Processing Record 46 of Set11 | general roca
# Processing Record 47 of Set11 | chaa-khol
# City not found. Skipping...
# Processing Record 48 of Set11 | cururupu
# Processing Record 49 of Set11 | mangai
# Processing Record 50 of Set11 | galle
# Processing Record 1 of Set12 | denpasar
# Processing Record 2 of Set12 | palamedu
# Processing Record 3 of Set12 | uchiza
# Processing Record 4 of Set12 | praia da vitoria
# Processing Record 5 of Set12 | brownsville
# Processing Record 6 of Set12 | lobito
# Processing Record 7 of Set12 | richards bay
# Processing Record 8 of Set12 | makarov
# Processing Record 9 of Set12 | songjianghe
# Processing Record 10 of Set12 | saryagash
# Processing Record 11 of Set12 | kuryk
# Processing Record 12 of Set12 | maragogi
# Processing Record 13 of Set12 | gamba
# Processing Record 14 of Set12 | riyadh
# Processing Record 15 of Set12 | luis correia
# Processing Record 16 of Set12 | zdunska wola
# Processing Record 17 of Set12 | talnakh
# Processing Record 18 of Set12 | hue
# Processing Record 19 of Set12 | trairi
# Processing Record 20 of Set12 | erzin
# Processing Record 21 of Set12 | lower hutt
# Processing Record 22 of Set12 | sao filipe
# Processing Record 23 of Set12 | coahuayana
# Processing Record 24 of Set12 | ha noi
# Processing Record 25 of Set12 | omboue
# Processing Record 26 of Set12 | tabuk
# Processing Record 27 of Set12 | dengzhou
# Processing Record 28 of Set12 | yaring
# Processing Record 29 of Set12 | indramayu
# Processing Record 30 of Set12 | maputo
# Processing Record 31 of Set12 | wiarton
# Processing Record 32 of Set12 | synya
# Processing Record 33 of Set12 | tuatapere
# Processing Record 34 of Set12 | batagay
# Processing Record 35 of Set12 | arrecife
# Processing Record 36 of Set12 | lahaina
# Processing Record 37 of Set12 | itoman
# Processing Record 38 of Set12 | novikovo
# Processing Record 39 of Set12 | angoram
# Processing Record 40 of Set12 | akot
# Processing Record 41 of Set12 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set12 | muroto
# Processing Record 43 of Set12 | el pardo
# Processing Record 44 of Set12 | quilmana
# Processing Record 45 of Set12 | jiaojiang
# Processing Record 46 of Set12 | harper
# Processing Record 47 of Set12 | karaul
# City not found. Skipping...
# Processing Record 48 of Set12 | egvekinot
# Processing Record 49 of Set12 | osoyoos
# Processing Record 50 of Set12 | abakaliki
# Processing Record 1 of Set13 | vallenar
# Processing Record 2 of Set13 | languyan
# Processing Record 3 of Set13 | san quintin
# Processing Record 4 of Set13 | les cayes
# Processing Record 5 of Set13 | tifton
# Processing Record 6 of Set13 | pudozh
# Processing Record 7 of Set13 | yerbogachen
# Processing Record 8 of Set13 | vagay
# Processing Record 9 of Set13 | vitre
# Processing Record 10 of Set13 | ocos
# Processing Record 11 of Set13 | ornskoldsvik
# Processing Record 12 of Set13 | vostok
# Processing Record 13 of Set13 | cesis
# Processing Record 14 of Set13 | neuquen
# Processing Record 15 of Set13 | yumen
# Processing Record 16 of Set13 | chongqing
# Processing Record 17 of Set13 | alice springs
# Processing Record 18 of Set13 | tripoli
# Processing Record 19 of Set13 | benton harbor
# Processing Record 20 of Set13 | bargi
# Processing Record 21 of Set13 | alexander city
# Processing Record 22 of Set13 | bundaberg
# Processing Record 23 of Set13 | palana
# Processing Record 24 of Set13 | lac du bonnet
# Processing Record 25 of Set13 | ust-maya
# Processing Record 26 of Set13 | gillette
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 575

# %%
city_data_df = pd.DataFrame(city_data)

#Rearrange the columns

column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Description']

city_data_df = city_data_df[column_order]

city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Hithadhoo      MV  -0.6000   73.0833     81.18        77          46
# 1     Balabac      PH   7.9868  117.0645     80.35        77          84
# 2    Yarmouth      US  41.7057  -70.2286     83.97        81          40
# 3  Karlskrona      SE  56.1616   15.5866     57.65        76          21
# 4     Rikitea      PF -23.1203 -134.9692     73.92        78          98
#
#    Wind Speed       Description
# 0        4.47  scattered clouds
# 1        3.11     broken clouds
# 2        8.05  scattered clouds
# 3        4.29        few clouds
# 4       16.33   overcast clouds

# %%
#create the output file (csv)

output_data_file = 'Weather_Database/WeatherPy_Database.csv'

#Export the city data into csv

city_data_df.to_csv(output_data_file, index_label = 'City_ID')
